# %%
# Import the necessary libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import geopandas as gpd

# %%
data = gpd.read_file('/home/h6x/git_projects/ornl-svi-data-processing/processed_data/SVI/SVI2018_MIN_MAX_SCALED_MISSING_REMOVED/GA/GA.shp')

# %%
data
# Out:
#       ST    STATE ST_ABBR STCNTY     COUNTY         FIPS  \
# 0     13  GEORGIA      GA  13009    Baldwin  13009970200
# 1     13  GEORGIA      GA  13009    Baldwin  13009970300
# 2     13  GEORGIA      GA  13009    Baldwin  13009970400
# 3     13  GEORGIA      GA  13013     Barrow  13013180103
# 4     13  GEORGIA      GA  13013     Barrow  13013180104
# ...   ..      ...     ...    ...        ...          ...
# 1947  13  GEORGIA      GA  13215   Muscogee  13215002500
# 1948  13  GEORGIA      GA  13215   Muscogee  13215011100
# 1949  13  GEORGIA      GA  13245   Richmond  13245011000
# 1950  13  GEORGIA      GA  13247   Rockdale  13247060201
# 1951  13  GEORGIA      GA  13313  Whitfield  13313000502
#
#                                            LOCATION  AREA_SQMI  E_TOTPOP  \
# 0        Census Tract 9702, Baldwin County, Georgia  11.224521      6763
# 1        Census Tract 9703, Baldwin County, Georgia  21.141800      6151
# ...

# %%
# get the rows where STCNTY is 13049
data_sample = data[data['STCNTY'] == '13061']

# %%
data_sample
# Out:
#       ST    STATE ST_ABBR STCNTY COUNTY         FIPS  \
# 1271  13  GEORGIA      GA  13061   Clay  13061960300
#
#                                      LOCATION  AREA_SQMI  E_TOTPOP  M_TOTPOP  \
# 1271  Census Tract 9603, Clay County, Georgia  195.40386      3001         0
#
#       ...  F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  MP_UNINSUR  E_DAYPOP  \
# 1271  ...        4        696        178       0.236         6.0      2120
#
#       Shape_Leng  Shape_Area  percentile  \
# 1271    1.317578    0.053484           1
#
#                                                geometry
# 1271  POLYGON ((-85.14095 31.78046, -85.10723 31.779...
#
# [1 rows x 128 columns]
