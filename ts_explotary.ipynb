# %%
# Import Libraries
import os
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
selected_variables = [
        'EP_UNEMP', 'EP_PCI', 'EP_NOHSDP', 'EP_UNINSUR', 'EP_AGE65', 'EP_AGE17', 'EP_DISABL', 
    'EP_SNGPNT', 'EP_LIMENG', 'EP_MINRTY', 'EP_MUNIT', 'EP_MOBILE', 'EP_CROWD', 'EP_NOVEH', 'EP_GROUPQ'
]

selected_variables_no_pci = [
        'EP_UNEMP', 'EP_NOHSDP', 'EP_UNINSUR', 'EP_AGE65', 'EP_AGE17', 'EP_DISABL', 
    'EP_SNGPNT', 'EP_LIMENG', 'EP_MINRTY', 'EP_MUNIT', 'EP_MOBILE', 'EP_CROWD', 'EP_NOVEH', 'EP_GROUPQ'
]

# %%
svi_2020 =gpd.read_file('/home/h6x/git_projects/data_processing/raw_data/svi/2020/SVI2020_US_tract.gdb')

# %%
col_names = svi_2020.columns.tolist()

# %%
# get the columns that starts with EP
ep_columns = [col for col in col_names if col.startswith('EP_')]

# %%
len(ep_columns)
# Out:
# 24

# %%
ep_columns
# Out:
# ['EP_POV150',
#  'EP_UNEMP',
#  'EP_HBURD',
#  'EP_NOHSDP',
#  'EP_UNINSUR',
#  'EP_AGE65',
#  'EP_AGE17',
#  'EP_DISABL',
#  'EP_SNGPNT',
#  'EP_LIMENG',
#  'EP_MINRTY',
#  'EP_MUNIT',
#  'EP_MOBILE',
#  'EP_CROWD',
#  'EP_NOVEH',
#  'EP_GROUPQ',
#  'EP_NOINT',
#  'EP_AFAM',
#  'EP_HISP',
#  'EP_ASIAN',
#  'EP_AIAN',
#  'EP_NHPI',
#  'EP_TWOMORE',
#  'EP_OTHERRACE']

# %%
svi_2020[selected_variables_no_pci]
# Out:
#        EP_UNEMP  EP_NOHSDP  EP_UNINSUR  EP_AGE65  EP_AGE17  EP_DISABL  \
# 0           2.1       14.3         9.6      15.2      21.4       21.3
# 1           4.0       10.6         5.9      16.2      18.5       11.0
# 2           2.7       12.8         3.5      12.6      25.1       14.0
# 3           2.4        6.2         4.8      27.4      14.4       19.6
# 4           1.0        8.8         3.2      12.6      26.4       14.0
# ...         ...        ...         ...       ...       ...        ...
# 84117       3.4        4.8         9.9      21.7      22.3       13.2
# 84118       2.5       10.0        13.9      18.0      24.6       13.9
# 84119       7.0       10.6        13.6      24.7      25.0       14.0
# 84120       3.2        8.5         8.9      21.7      16.8       15.1
# 84121       4.5        4.9        14.2      19.0      21.5       13.4
#
#        EP_SNGPNT  EP_LIMENG  EP_MINRTY  EP_MUNIT  EP_MOBILE  EP_CROWD  \
# ...
