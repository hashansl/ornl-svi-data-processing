# %%
import os
import warnings

import geopandas as gpd
import pandas as pd
import numpy as np

# %%
svi_path = '/home/h6x/git_projects/ornl-svi-data-processing/raw_data/svi/2018/SVI2018_US_tract.gdb'
overdose_path = '/home/h6x/Projects/overdose_modeling/data/HepVu_County_Opioid_Indicators_05DEC22.xlsx'

# %%
def preprocess_overdose_data(overdose_df):
    """Preprocess overdose data."""
    overdose_df['GEO ID'] = overdose_df['GEO ID'].astype(str)
    overdose_df['GEO ID'] = overdose_df['GEO ID'].apply(lambda x: x.zfill(5))
    return overdose_df

# %%
overdose_df = pd.read_excel(overdose_path)

# %%
overdose_df = preprocess_overdose_data(overdose_df)

# %%
overdose_df.head()
# Out:
#   GEO ID State Abbreviation     County Name  Opioid Prescription Rate 2020  \
# 0  01001                 AL  Autauga County                           98.3
# 1  01003                 AL  Baldwin County                           65.0
# 2  01005                 AL  Barbour County                           22.8
# 3  01007                 AL     Bibb County                           24.8
# 4  01009                 AL   Blount County                           22.8
#
#    Narcotic Overdose Mortality Rate 2014  \
# 0                                    8.2
# 1                                   18.0
# 2                                    4.4
# 3                                   17.2
# 4                                   18.6
#
#    Narcotic Overdose Mortality Rate 2015  \
# 0                                    8.8
# 1                                   20.0
# 2                                    4.5
# 3                                   16.6
# 4                                   18.9
#
#    Narcotic Overdose Mortality Rate 2016  \
# 0                                   10.7
# 1                                   16.6
# 2                                    5.7
# 3                                   22.6
# 4                                   22.7
#
#    Narcotic Overdose Mortality Rate 2017  \
# 0                                    9.8
# 1                                   15.1
# 2                                    5.8
# 3                                   21.7
# 4                                   27.0
#
#    Narcotic Overdose Mortality Rate 2018  \
# 0                                   10.9
# 1                                   14.9
# 2                                    5.2
# 3                                   23.1
# 4                                   19.9
#
#    Narcotic Overdose Mortality Rate 2019  \
# 0                                    9.2
# 1                                   14.5
# 2                                    5.7
# 3                                   19.4
# 4                                   20.3
#
#    Narcotic Overdose Mortality Rate 2020
# 0                                   11.6
# 1                                   27.4
# 2                                    7.6
# 3                                   27.3
# 4                                   24.2

# %%
def preprocess_svi_data(us_svi, raw_variables):
    """Preprocess SVI data by removing invalid values and normalizing."""
    # for variable in raw_variables:
        # us_svi = us_svi[us_svi[variable] != -999.00]

    for var in raw_variables:
        max_val = us_svi[var].max()
        min_val = us_svi[var].min()
        us_svi[var] = (us_svi[var] - min_val) / (max_val - min_val)
    
    return us_svi

# %%
us_svi = gpd.read_file(svi_path)

# %%
us_svi.head()
# Out:
#    ST    STATE ST_ABBR STCNTY   COUNTY         FIPS  \
# 0  01  ALABAMA      AL  01015  Calhoun  01015981901
# 1  01  ALABAMA      AL  01015  Calhoun  01015981902
# 2  01  ALABAMA      AL  01015  Calhoun  01015981903
# 3  01  ALABAMA      AL  01097   Mobile  01097003605
# 4  01  ALABAMA      AL  01097   Mobile  01097990000
#
#                                         LOCATION  AREA_SQMI  E_TOTPOP  \
# 0  Census Tract 9819.01, Calhoun County, Alabama  24.243865         0
# 1  Census Tract 9819.02, Calhoun County, Alabama  34.646714         0
# 2  Census Tract 9819.03, Calhoun County, Alabama  13.926276         0
# 3     Census Tract 36.05, Mobile County, Alabama   0.732300       899
# 4      Census Tract 9900, Mobile County, Alabama   0.000000         0
#
#    M_TOTPOP  ...  F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  \
# 0        12  ...      -999     -999          0         12      -999.0
# 1        12  ...      -999     -999          0         12      -999.0
# 2        12  ...      -999     -999          0         12      -999.0
# 3       316  ...      -999     -999         33         36         3.7
# 4        12  ...      -999     -999          0         12      -999.0
#
#    MP_UNINSUR  E_DAYPOP  Shape_Length  Shape_Area  \
# 0      -999.0       656      0.339400    0.006105
# 1      -999.0       146      0.420459    0.008752
# 2      -999.0         0      0.330164    0.003508
# 3         4.1      5135      0.060725    0.000180
# 4      -999.0         0      0.105380    0.000536
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.01323 33.68426, -86.01224 ...
# 1  MULTIPOLYGON (((-86.01730 33.69662, -86.01704 ...
# 2  MULTIPOLYGON (((-85.78501 33.66554, -85.78318 ...
# 3  MULTIPOLYGON (((-88.19230 30.69524, -88.19097 ...
# 4  MULTIPOLYGON (((-88.05337 30.50699, -88.05109 ...
#
# [5 rows x 127 columns]

# %%
raw_variables = [
    'EP_POV', 'EP_UNEMP', 'EP_NOHSDP', 'EP_UNINSUR', 'EP_AGE65',
    'EP_AGE17', 'EP_DISABL', 'EP_SNGPNT', 'EP_LIMENG', 'EP_MINRTY', 'EP_MUNIT',
    'EP_MOBILE', 'EP_CROWD', 'EP_NOVEH', 'EP_GROUPQ'
]

# %%
svi_df = preprocess_svi_data(us_svi, raw_variables)

# %%
svi_df.head()
# Out:
#      ST    STATE ST_ABBR STCNTY   COUNTY         FIPS  \
# 609  01  ALABAMA      AL  01001  Autauga  01001020100
# 610  01  ALABAMA      AL  01001  Autauga  01001020300
# 611  01  ALABAMA      AL  01001  Autauga  01001020400
# 612  01  ALABAMA      AL  01001  Autauga  01001020500
# 613  01  ALABAMA      AL  01001  Autauga  01001020801
#
#                                          LOCATION  AREA_SQMI  E_TOTPOP  \
# 609     Census Tract 201, Autauga County, Alabama   3.790677      1923
# 610     Census Tract 203, Autauga County, Alabama   2.065365      3476
# 611     Census Tract 204, Autauga County, Alabama   2.464982      3831
# 612     Census Tract 205, Autauga County, Alabama   4.404987      9883
# 613  Census Tract 208.01, Autauga County, Alabama  47.981925      2826
#
#      M_TOTPOP  ...  F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  \
# 609       253  ...         0        0        178         79       0.093
# 610       433  ...         0        1        119         81       0.034
# 611       337  ...         0        0        108        100       0.028
# 612       726  ...         0        0        398        223       0.042
# 613       324  ...         0        0        144         84       0.051
#
#      MP_UNINSUR  E_DAYPOP  Shape_Length  Shape_Area  \
# 609         4.1      1018      0.150082    0.000948
# 610         2.2      1836      0.100175    0.000516
# 611         2.6      1951      0.114106    0.000609
# 612         2.4      8342      0.159359    0.001099
# 613         2.9      1331      0.587644    0.012689
#
#                                               geometry
# 609  MULTIPOLYGON (((-86.50916 32.47344, -86.50620 ...
# 610  MULTIPOLYGON (((-86.47087 32.47573, -86.46964 ...
# 611  MULTIPOLYGON (((-86.45394 32.49318, -86.44742 ...
# 612  MULTIPOLYGON (((-86.43816 32.45069, -86.43773 ...
# 613  MULTIPOLYGON (((-86.59535 32.38272, -86.59454 ...
#
# [5 rows x 127 columns]
